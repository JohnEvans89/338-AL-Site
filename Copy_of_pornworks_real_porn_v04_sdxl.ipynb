# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnEvans89/338-AL-Site/blob/main/Copy_of_pornworks_real_porn_v04_sdxl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U diffusers

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/John6666/pornworks-real-porn-v04-sdxl
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/John6666/pornworks-real-porn-v04-sdxl)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
pip install -U diffusers transformers accelerate

# %%
import torch
from diffusers import DiffusionPipeline

# switch to "mps" for apple devices
pipe = DiffusionPipeline.from_pretrained("John6666/pornworks-real-porn-v04-sdxl")
pipe.to("cuda", dtype=torch.bfloat16)

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# ...
# Loading weights:   0%|          | 0/517 [00:00<?, ?it/s]
